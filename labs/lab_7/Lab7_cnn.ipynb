# %% [markdown]
# <a href="https://colab.research.google.com/github/JAntonioRosales/CE888-Data-Science/blob/main/labs/lab_7/Lab7_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CE888 Lab 7
# Dr Ana Matran-Fernandez,  University of Essex.
#
# ## Training a CNN Classifier
#
# - Lab Objective: Create, train, and test a CNN model
#
# ### Instructions:
#
# 1. Go through each code block,
#  study and make sure you understand each of them,
#  and fill in the missing "TODO" parts.
#
# 2. Save a neural network for the MNIST dataset and run it as an attachment through the Moodle CE888 Lab 7 quiz.
#
# 3. Save a neural network for the Cifar10 dataset and run it as an attachment through the Moodle CE888 Lab 7 quiz.
#
# 4. If you have time, work through the "checklist of things to do" in the final block of this page.
#
# Before you start (if you're running this locally; this is not necessary on Colab):
# - Check you have the python packages numpy, matplotlib, tensorflow.
# - e.g., install them with "pip3 install numpy, matplotlib, tensorflow"
#
# Acknowledgements:
# - This lab session is based on Dr Michael Fairbank's CE811 materials.

# %%
# Imports
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load a vision benchmark dataset
#
# - We will start with the MNIST hand-written numeric digits dataset.

# %%
dataset_name = "mnist"

if dataset_name == "cifar10":
    dataset = tf.keras.datasets.cifar10
    class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer','dog', 'frog', 'horse', 'ship', 'truck']
    # CIFAR10 images are 32*32*3.
    accuracy_threshold = 0.6  # Moodle progress checker expects >60% accuracy on CIFAR10
elif dataset_name == "fashion":
    dataset = tf.keras.datasets.fashion_mnist
    class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
    accuracy_threshold = 0.8
elif dataset_name == "mnist":
    accuracy_threshold = 0.96  # Moodle progress checker expects >96% accuracy on MNIST.
    dataset = tf.keras.datasets.mnist
    class_names = ['zero', 'one', 'two', 'three', 'four','five', 'six', 'seven', 'eight', 'nine']
else:
    print("unknown dataset")
    raise Exception("Please specify a valid dataset!")

(train_images0, train_labels0), (test_images0, test_labels0) = dataset.load_data()

print('Train: X=%s, y=%s' % (train_images0.shape, train_labels0.shape))
print('Test: X=%s, y=%s' % (test_images0.shape, test_labels0.shape))

train_labels = train_labels0.reshape(-1)
test_labels = test_labels0.reshape(-1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %% [markdown]
# ## Visualise the Dataset
#
# - Show a few pictures of the images we are trying to learn from...

# %%
# plot a few images
plt.figure(figsize=(10,10))
for i in range(25):
    # define subplot
    plt.subplot(5,5,i+1)
    # plot raw pixel data
    plt.imshow(train_images0[i], cmap=plt.get_cmap('gray'))
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    if class_names != None:
        # Add a label underneath, if we have one...
        plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ## Prep the data
# - The keras datasets contain integer pixel intensities from 0 to 255.  We must rescale this to floats from 0 to 1.

# %%
# Rescale greyscale from 8 bit to floating point (by dividing by 255)
test_images = (test_images0 / 255.0).astype(np.float32) # 10000 test patterns, shape 10000*28*28 (10000 images, 28 px in y, 28 px in x)
train_images = (train_images0 / 255.0).astype(np.float32) # 60000 train patterns, shape 60000*28*28

if len(train_images.shape) == 3:  # images must be rank-4 tensors [number_of_images, dimension1, dimension2, number_of_channels]
    # add a single channel to these black-and-white images
    train_images=train_images.reshape(list(train_images.shape)+[1])
    test_images=test_images.reshape(list(test_images.shape)+[1])
    print("Reshaped images from ", train_images0.shape, "to", train_images.shape, "so that 'channel' dimension exists")

num_classification_categories = train_labels.max() + 1
# Out:
# Reshaped images from  (60000, 28, 28) to (60000, 28, 28, 1) so that 'channel' dimension exists

# %% [markdown]
# ## Define a model
# - This means build our neural network here.
# - TODO modify the simple model defined below
#  so that it has the following structure.
# - Use relu activation functions everywhere,
#  except for the last layer which must have a softmax activation function.
# - Use kernel size (3, 3) for each convolutional layer
#  and pool size (2, 2) for each max-pooling layer.
#  Ensure you obtain the architecture exactly as shown here...
#
# ```
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Conv2D)              (None, 28, 28, 6)         60
# _________________________________________________________________
# layer2 (MaxPooling2D)        (None, 14, 14, 6)         0
# _________________________________________________________________
# layer3 (Conv2D)              (None, 14, 14, 3)         165
# _________________________________________________________________
# layer4 (MaxPooling2D)        (None, 7, 7, 3)           0
# _________________________________________________________________
# layer5 (Flatten)             (None, 147)               0
# _________________________________________________________________
# layer6 (Dense)               (None, 128)               18944
# _________________________________________________________________
# layer7 (Dense)               (None, 10)                1290
# =================================================================
# Total params: 20,459
# Trainable params: 20,459
# Non-trainable params: 0
# _________________________________________________________________
#
# ```

# %%
# build model with CNN architecture
model = keras.Sequential()

model.add(layers.Conv2D(filters=6, kernel_size=3, activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Conv2D(filters=3, kernel_size=3, activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Flatten())

model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(num_classification_categories, activation='softmax'))

# %% [markdown]
# ## View Model Summary
#
# - Have a look at the model summary here and compare with the output above to make sure they're the same.

# %%
model.build(input_shape=(None,) + train_images.shape[1:])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 28, 28, 6)         60
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 6)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 3)         165
#
#  max_pooling2d_7 (MaxPooling  (None, 7, 7, 3)          0
#  2D)
#
#  flatten_3 (Flatten)         (None, 147)               0
#
#  dense_6 (Dense)             (None, 128)               18944
#
#  dense_7 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 20,459
# Trainable params: 20,459
# Non-trainable params: 0
# _________________________________________________________________

# %%
if model.count_params() > 800000 and dataset_name == "cifar10":
    print("The lab7 quiz has a 10MB limit on your model size, so use a smaller model if you want to validate through the auto-marker!")

# %% [markdown]
# ## Train the network

# %%
optimizer = keras.optimizers.Adam()

model.compile(optimizer=optimizer,  
              loss=keras.losses.SparseCategoricalCrossentropy(), 
              metrics=['accuracy'])

history = model.fit(train_images, train_labels,
                batch_size=128,
                epochs=5,
                validation_data=(test_images, test_labels))
# Out:
# Epoch 1/5
# 469/469 [==============================] - 12s 4ms/step - loss: 0.4495 - accuracy: 0.8683 - val_loss: 0.1657 - val_accuracy: 0.9525
# Epoch 2/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1442 - accuracy: 0.9560 - val_loss: 0.1130 - val_accuracy: 0.9646
# Epoch 3/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1094 - accuracy: 0.9656 - val_loss: 0.0977 - val_accuracy: 0.9700
# Epoch 4/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0911 - accuracy: 0.9723 - val_loss: 0.0730 - val_accuracy: 0.9766
# Epoch 5/5
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0782 - accuracy: 0.9760 - val_loss: 0.0801 - val_accuracy: 0.9741

# %% [markdown]
# ## Plot graphs of learning progress...
#
# - Have a look at these graphs, and try to work out whether any
#  overfitting has occurred, or whether we would gain any benefit
#  from training for more or fewer epochs (TODO)

# %%
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %%
# We can see a bit of overfitting because... FALTAAA

# %% [markdown]
# ## Inspect how well the system is working...
# - The test set has a lot of images in it,
#  but we can only view 25 at a time.
# - Hence rerun this code block several times,
#  to get a different random set of samples from the test set (TODO)

# %%
plt.figure(figsize=(10,11))
# plot 25 random images from the test set.
first_index = np.random.randint(len(test_images)-25)
for i in range(first_index,first_index+25):
    # define subplot
    plt.subplot(5,5,i+1-first_index)
    # plot raw pixel data
    plt.imshow(test_images0[i], cmap=plt.get_cmap('gray'))
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    if class_names != None:
        # Add a label underneath, if we have one...
        prediction = model(test_images[i:i+1])[0,:] # array of the probabilities of belonging to each class
        prediction_class = np.argmax(prediction) # position of the max probability in the array
        true_label = test_labels[i]
        class_name = class_names[prediction_class]
        plt.xlabel(class_name+" "+("CORRECT" if prediction_class==true_label else "WRONG\n{}".format(class_names[true_label])))
plt.subplots_adjust(hspace=0.2)
plt.show()

# %% [markdown]
# ## Save the model
# - Once you have the correct layers created (as described above)
#  and have trained a model which can score >96% on the
#  MNIST digits validation set, save your model with the next code block.
# - Then use your saved model as an attachment to pass questions 1+2 of
#  the Lab 7 Quiz on Moodle.

# %%
if history.history["val_accuracy"][-1] > accuracy_threshold:
    print("Your model is accurate enough!")
    # Save the model into a local folder
    keras.models.save_model(model, "Model1"+dataset_name+".h5",save_format='h5')
else:
    print("Accuracy is below the threshold!")
    raise Exception("Your model isn't accurate enough to pass the progress checker!")
# Out:
# Your model is accurate enough!

# %% [markdown]
# # CIFAR10 image set
#
# - Next try and learn the CIFAR10 image set
# - Repeat all of the steps above, but change the dataset_name in the
#  top code-block to "cifar10"
# - We need a bigger network for CIFAR10 than we did for MNIST.
#  Use this architecture:
#
# ```
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer1 (Conv2D)              (None, 32, 32, 16)        448
# _________________________________________________________________
# layer2 (Conv2D)              (None, 32, 32, 32)        4640
# _________________________________________________________________
# layer3 (MaxPooling2D)        (None, 16, 16, 32)        0
# _________________________________________________________________
# layer4 (Dropout)             (None, 16, 16, 32)        0
# _________________________________________________________________
# layer5 (Conv2D)              (None, 16, 16, 64)        18496
# _________________________________________________________________
# layer6 (Conv2D)              (None, 16, 16, 64)        36928
# _________________________________________________________________
# layer7 (MaxPooling2D)        (None, 8, 8, 64)          0
# _________________________________________________________________
# layer8 (Dropout)             (None, 8, 8, 64)          0
# _________________________________________________________________
# layer9 (Flatten)             (None, 4096)              0
# _________________________________________________________________
# layer10 (Dense)              (None, 128)               524416
# _________________________________________________________________
# layer11 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 586,218
# Trainable params: 586,218
# Non-trainable params: 0
# _________________________________________________________________
# ```
#
# - For the dropout layers, use a Dropout rate of 0.2
# - Train for at least 5 epochs,
#  and you should be able to score >60% on the test set for CIFAR10.
# - Note that the above architecture is still pretty small
#  (particularly, by only having 64 filters).
#  But we need this particular smaller architecture,
#  so that the auto-marker can handle it comfortably.
#
# Once you have this working, upload your saved model to questions 3+4 of the progress checker.

# %% [markdown]
# #### Load

# %%
dataset_name = "cifar10"

if dataset_name == "cifar10":
    dataset = tf.keras.datasets.cifar10
    class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer','dog', 'frog', 'horse', 'ship', 'truck']
    # CIFAR10 images are 32*32*3.
    accuracy_threshold = 0.6  # Moodle progress checker expects >60% accuracy on CIFAR10
elif dataset_name == "fashion":
    dataset = tf.keras.datasets.fashion_mnist
    class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
    accuracy_threshold = 0.8
elif dataset_name == "mnist":
    accuracy_threshold = 0.96  # Moodle progress checker expects >96% accuracy on MNIST.
    dataset = tf.keras.datasets.mnist
    class_names = ['zero', 'one', 'two', 'three', 'four','five', 'six', 'seven', 'eight', 'nine']
else:
    print("unknown dataset")
    raise Exception("Please specify a valid dataset!")

(train_images0, train_labels0), (test_images0, test_labels0) = dataset.load_data()

print('Train: X=%s, y=%s' % (train_images0.shape, train_labels0.shape))
print('Test: X=%s, y=%s' % (test_images0.shape, test_labels0.shape))

train_labels = train_labels0.reshape(-1)
test_labels = test_labels0.reshape(-1)
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %% [markdown]
# #### Visualise

# %%
# plot a few images
plt.figure(figsize=(10,10))
for i in range(25):
    # define subplot
    plt.subplot(5,5,i+1)
    # plot raw pixel data
    plt.imshow(train_images0[i], cmap=plt.get_cmap('gray'))
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    if class_names != None:
        # Add a label underneath, if we have one...
        plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# #### Prep

# %%
# Rescale greyscale from 8 bit to floating point (by dividing by 255)
test_images = (test_images0 / 255.0).astype(np.float32) # 10000 test patterns, shape 10000*32*32*3 (10000 images, 32 px in y, 32 px in x, 3 channels)
train_images = (train_images0 / 255.0).astype(np.float32) # 50000 train patterns, shape 50000*32*32*3

if len(train_images.shape) == 3:  # images must be rank-4 tensors [number_of_images, dimension1, dimension2, number_of_channels]
    # add a single channel to these black-and-white images
    train_images=train_images.reshape(list(train_images.shape)+[1])
    test_images=test_images.reshape(list(test_images.shape)+[1])
    print("Reshaped images from ", train_images0.shape, "to", train_images.shape, "so that 'channel' dimension exists")

num_classification_categories = train_labels.max() + 1

# %% [markdown]
# #### Define model

# %%
# build model with CNN architecture
model = keras.Sequential()

model.add(layers.Conv2D(filters=16, kernel_size=3, activation='relu', padding='same'))
model.add(layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add(layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.2))
model.add(layers.Flatten())

model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(num_classification_categories, activation='softmax'))

# %% [markdown]
# #### Model summary

# %%
model.build(input_shape=(None,) + train_images.shape[1:])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 32, 32, 16)        448
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)        4640
#
#  max_pooling2d_10 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_11 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 8, 8, 64)          0
#
#  flatten_5 (Flatten)         (None, 4096)              0
#
#  dense_10 (Dense)            (None, 128)               524416
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 586,218
# Trainable params: 586,218
# Non-trainable params: 0
# _________________________________________________________________

# %%
if model.count_params() > 800000 and dataset_name == "cifar10":
    print("The lab7 quiz has a 10MB limit on your model size, so use a smaller model if you want to validate through the auto-marker!")

# %% [markdown]
# #### Train

# %%
optimizer = keras.optimizers.Adam()

model.compile(optimizer=optimizer,  
              loss=keras.losses.SparseCategoricalCrossentropy(), 
              metrics=['accuracy'])

history = model.fit(train_images, train_labels,
                batch_size=128,
                epochs=10,
                validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 391/391 [==============================] - 5s 11ms/step - loss: 1.5675 - accuracy: 0.4319 - val_loss: 1.2692 - val_accuracy: 0.5438
# Epoch 2/10
# 391/391 [==============================] - 4s 11ms/step - loss: 1.1311 - accuracy: 0.5980 - val_loss: 1.0342 - val_accuracy: 0.6316
# Epoch 3/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.9588 - accuracy: 0.6609 - val_loss: 0.8970 - val_accuracy: 0.6816
# Epoch 4/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.8564 - accuracy: 0.6997 - val_loss: 0.8418 - val_accuracy: 0.7037
# Epoch 5/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.7856 - accuracy: 0.7229 - val_loss: 0.8193 - val_accuracy: 0.7154
# Epoch 6/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.7146 - accuracy: 0.7472 - val_loss: 0.7681 - val_accuracy: 0.7364
# Epoch 7/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.6609 - accuracy: 0.7683 - val_loss: 0.7603 - val_accuracy: 0.7370
# Epoch 8/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.6110 - accuracy: 0.7838 - val_loss: 0.7469 - val_accuracy: 0.7390
# Epoch 9/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.5650 - accuracy: 0.7994 - val_loss: 0.7252 - val_accuracy: 0.7554
# Epoch 10/10
# 391/391 [==============================] - 4s 10ms/step - loss: 0.5245 - accuracy: 0.8160 - val_loss: 0.7275 - val_accuracy: 0.7572

# %% [markdown]
# #### Train progress graphs

# %%
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %%
# Can do more epochs, validation set (after 5 epochs) is still rising, so we can assume it still hasn't overfitted.

# %%
# EDIT - After training for 10 epochs we hit a plateau around 75% accuracy on the validation set. We can stop training after approximately 6 or 7 epochs.

# %% [markdown]
# #### Inspect

# %%
plt.figure(figsize=(10,11))
# plot 25 random images from the test set.
first_index = np.random.randint(len(test_images)-25)
for i in range(first_index,first_index+25):
    # define subplot
    plt.subplot(5,5,i+1-first_index)
    # plot raw pixel data
    plt.imshow(test_images0[i], cmap=plt.get_cmap('gray'))
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    if class_names != None:
        # Add a label underneath, if we have one...
        prediction = model(test_images[i:i+1])[0,:] # array of the probabilities of belonging to each class
        prediction_class = np.argmax(prediction) # position of the max probability in the array
        true_label = test_labels[i]
        class_name = class_names[prediction_class]
        plt.xlabel(class_name+" "+("CORRECT" if prediction_class==true_label else "WRONG\n{}".format(class_names[true_label])))
plt.subplots_adjust(hspace=0.2)
plt.show()

# %% [markdown]
# #### Save the model

# %%
if history.history["val_accuracy"][-1] > accuracy_threshold:
    print("Your model is accurate enough!")
    # Save the model into a local folder
    keras.models.save_model(model, "Model1"+dataset_name+".h5",save_format='h5')
else:
    print("Accuracy is below the threshold!")
    raise Exception("Your model isn't accurate enough to pass the progress checker!")
# Out:
# Your model is accurate enough!

# %% [markdown]
# ## Checklist of further things to do
#
# Okay you should have completed the progress checker by now.
# But if you want to explore further, then...
#
# 1. Check you have made 2 different convolutional neural network classifiers, one for MNIST and one for Cifar10.
#
# 2. Check that in each case you have inspected the results,
#  the validation accuracy and decided whether more or fewer epochs
#  would be beneficial.
#
# 3. If you have time remaining then see if you can improve performance
#  on Cifar10.
#     * Possible methods:
#         * Try training for longer.
#         * Add more convolutional layers.
#         * Add more filters at each convolutional layer.
#     * Have a look at the CNN structure used here (https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/) to see how you could score >80% on CIFAR10 (see the final architecture at the bottom of the page). However, this requires a lot of CPU/GPU time.
#
# 4. If time permits, then see what the effect of changing the relu activation functions to tanh.

# %% [markdown]
# #### Improving performance
# * Training for 30 epochs
# * Adding more layers
# * Adding more filters

# %%
# build model with CNN architecture
model = keras.Sequential()

model.add(layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'))
model.add(layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add(layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.3))

model.add(layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'))
model.add(layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.4))

model.add(layers.Flatten())

model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(num_classification_categories, activation='softmax'))

# %%
model.build(input_shape=(None,) + train_images.shape[1:])
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_28 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_18 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_30 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_31 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_19 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_32 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_33 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_20 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 4, 4, 128)         0
#
#  flatten_8 (Flatten)         (None, 2048)              0
#
#  dense_16 (Dense)            (None, 128)               262272
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_17 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 550,570
# Trainable params: 550,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()

model.compile(optimizer=optimizer,  
              loss=keras.losses.SparseCategoricalCrossentropy(), 
              metrics=['accuracy'])

history = model.fit(train_images, train_labels,
                batch_size=128,
                epochs=30,
                validation_data=(test_images, test_labels))
# Out:
# Epoch 1/30
# 391/391 [==============================] - 7s 16ms/step - loss: 1.8060 - accuracy: 0.3247 - val_loss: 1.4394 - val_accuracy: 0.4643
# Epoch 2/30
# 391/391 [==============================] - 6s 14ms/step - loss: 1.4079 - accuracy: 0.4867 - val_loss: 1.1914 - val_accuracy: 0.5691
# Epoch 3/30
# 391/391 [==============================] - 6s 14ms/step - loss: 1.1979 - accuracy: 0.5735 - val_loss: 1.0276 - val_accuracy: 0.6385
# Epoch 4/30
# 391/391 [==============================] - 5s 14ms/step - loss: 1.0565 - accuracy: 0.6264 - val_loss: 0.9484 - val_accuracy: 0.6606
# Epoch 5/30
# 391/391 [==============================] - 6s 14ms/step - loss: 0.9557 - accuracy: 0.6643 - val_loss: 0.8301 - val_accuracy: 0.7048
# Epoch 6/30
# 391/391 [==============================] - 6s 15ms/step - loss: 0.8790 - accuracy: 0.6916 - val_loss: 0.8334 - val_accuracy: 0.7079
# Epoch 7/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.8295 - accuracy: 0.7104 - val_loss: 0.7204 - val_accuracy: 0.7477
# Epoch 8/30
# 391/391 [==============================] - 6s 15ms/step - loss: 0.7797 - accuracy: 0.7282 - val_loss: 0.6813 - val_accuracy: 0.7663
# Epoch 9/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.7411 - accuracy: 0.7409 - val_loss: 0.6680 - val_accuracy: 0.7716
# Epoch 10/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.7136 - accuracy: 0.7545 - val_loss: 0.6724 - val_accuracy: 0.7704
# Epoch 11/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.6801 - accuracy: 0.7637 - val_loss: 0.6110 - val_accuracy: 0.7902
# Epoch 12/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.6475 - accuracy: 0.7771 - val_loss: 0.6198 - val_accuracy: 0.7934
# Epoch 13/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.6342 - accuracy: 0.7817 - val_loss: 0.6092 - val_accuracy: 0.7925
# Epoch 14/30
# 391/391 [==============================] - 6s 14ms/step - loss: 0.6106 - accuracy: 0.7891 - val_loss: 0.5865 - val_accuracy: 0.8007
# Epoch 15/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.6009 - accuracy: 0.7934 - val_loss: 0.5831 - val_accuracy: 0.8010
# Epoch 16/30
# 391/391 [==============================] - 6s 14ms/step - loss: 0.5855 - accuracy: 0.7971 - val_loss: 0.5895 - val_accuracy: 0.8057
# Epoch 17/30
# 391/391 [==============================] - 6s 14ms/step - loss: 0.5612 - accuracy: 0.8057 - val_loss: 0.5739 - val_accuracy: 0.8111
# Epoch 18/30
# 391/391 [==============================] - 6s 14ms/step - loss: 0.5592 - accuracy: 0.8074 - val_loss: 0.6263 - val_accuracy: 0.7936
# Epoch 19/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.5507 - accuracy: 0.8114 - val_loss: 0.5585 - val_accuracy: 0.8172
# Epoch 20/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.5451 - accuracy: 0.8111 - val_loss: 0.5660 - val_accuracy: 0.8121
# Epoch 21/30
# 391/391 [==============================] - 6s 15ms/step - loss: 0.5252 - accuracy: 0.8179 - val_loss: 0.5668 - val_accuracy: 0.8099
# Epoch 22/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.5131 - accuracy: 0.8241 - val_loss: 0.5526 - val_accuracy: 0.8136
# Epoch 23/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.5007 - accuracy: 0.8277 - val_loss: 0.5676 - val_accuracy: 0.8149
# Epoch 24/30
# 391/391 [==============================] - 6s 14ms/step - loss: 0.4953 - accuracy: 0.8283 - val_loss: 0.5805 - val_accuracy: 0.8057
# Epoch 25/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.4929 - accuracy: 0.8290 - val_loss: 0.5547 - val_accuracy: 0.8226
# Epoch 26/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.4822 - accuracy: 0.8335 - val_loss: 0.5454 - val_accuracy: 0.8238
# Epoch 27/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.4793 - accuracy: 0.8347 - val_loss: 0.5717 - val_accuracy: 0.8179
# Epoch 28/30
# 391/391 [==============================] - 6s 14ms/step - loss: 0.4751 - accuracy: 0.8367 - val_loss: 0.5779 - val_accuracy: 0.8151
# Epoch 29/30
# 391/391 [==============================] - 6s 14ms/step - loss: 0.4688 - accuracy: 0.8382 - val_loss: 0.5606 - val_accuracy: 0.8160
# Epoch 30/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.4630 - accuracy: 0.8399 - val_loss: 0.5612 - val_accuracy: 0.8212

# %%
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %% [markdown]
# #### Changing activation method
# relu --> tanh

# %%
# build model with CNN architecture
model = keras.Sequential()

model.add(layers.Conv2D(filters=32, kernel_size=3, activation='tanh', padding='same'))
model.add(layers.Conv2D(filters=32, kernel_size=3, activation='tanh', padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(filters=64, kernel_size=3, activation='tanh', padding='same'))
model.add(layers.Conv2D(filters=64, kernel_size=3, activation='tanh', padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.3))

model.add(layers.Conv2D(filters=128, kernel_size=3, activation='tanh', padding='same'))
model.add(layers.Conv2D(filters=128, kernel_size=3, activation='tanh', padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.4))

model.add(layers.Flatten())

model.add(layers.Dense(128, activation='tanh'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(num_classification_categories, activation='softmax'))

# %%
model.build(input_shape=(None,) + train_images.shape[1:])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_34 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_35 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_21 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_36 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_37 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_22 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_38 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_39 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_23 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  dropout_18 (Dropout)        (None, 4, 4, 128)         0
#
#  flatten_9 (Flatten)         (None, 2048)              0
#
#  dense_18 (Dense)            (None, 128)               262272
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_19 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 550,570
# Trainable params: 550,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam()

model.compile(optimizer=optimizer,  
              loss=keras.losses.SparseCategoricalCrossentropy(), 
              metrics=['accuracy'])

history = model.fit(train_images, train_labels,
                batch_size=128,
                epochs=10,
                validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 391/391 [==============================] - 7s 16ms/step - loss: 1.5427 - accuracy: 0.4471 - val_loss: 1.1755 - val_accuracy: 0.5877
# Epoch 2/10
# 391/391 [==============================] - 6s 15ms/step - loss: 1.1593 - accuracy: 0.5967 - val_loss: 0.9440 - val_accuracy: 0.6724
# Epoch 3/10
# 391/391 [==============================] - 5s 14ms/step - loss: 1.0547 - accuracy: 0.6331 - val_loss: 0.8998 - val_accuracy: 0.6909
# Epoch 4/10
# 391/391 [==============================] - 5s 14ms/step - loss: 0.9915 - accuracy: 0.6565 - val_loss: 0.8707 - val_accuracy: 0.7012
# Epoch 5/10
# 391/391 [==============================] - 6s 14ms/step - loss: 0.9447 - accuracy: 0.6733 - val_loss: 0.8236 - val_accuracy: 0.7148
# Epoch 6/10
# 391/391 [==============================] - 5s 14ms/step - loss: 0.9293 - accuracy: 0.6801 - val_loss: 0.8077 - val_accuracy: 0.7246
# Epoch 7/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.9066 - accuracy: 0.6900 - val_loss: 0.7907 - val_accuracy: 0.7285
# Epoch 8/10
# 391/391 [==============================] - 6s 14ms/step - loss: 0.8965 - accuracy: 0.6913 - val_loss: 0.8036 - val_accuracy: 0.7175
# Epoch 9/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.8830 - accuracy: 0.6974 - val_loss: 0.7778 - val_accuracy: 0.7309
# Epoch 10/10
# 391/391 [==============================] - 6s 15ms/step - loss: 0.8724 - accuracy: 0.6996 - val_loss: 0.7855 - val_accuracy: 0.7280

# %%
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
